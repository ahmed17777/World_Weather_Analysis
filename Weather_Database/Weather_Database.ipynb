# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lat and lng to a list 
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
   
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | dolores
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | kaitangata
# Processing Record 5 of Set 1 | camiri
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | saint anthony
# Processing Record 8 of Set 1 | margate
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | galesong
# Processing Record 13 of Set 1 | gao
# Processing Record 14 of Set 1 | victoria
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | alyangula
# Processing Record 19 of Set 1 | husavik
# Processing Record 20 of Set 1 | boysun
# Processing Record 21 of Set 1 | santander
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | homer
# Processing Record 26 of Set 1 | price
# Processing Record 27 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | iqaluit
# Processing Record 34 of Set 1 | te anau
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | arman
# Processing Record 37 of Set 1 | vanimo
# Processing Record 38 of Set 1 | fairbanks
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | yumen
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | bambous virieux
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | pacific grove
# Processing Record 50 of Set 1 | mandalgovi
# Processing Record 1 of Set 2 | gravdal
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | comodoro rivadavia
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | tiznit
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | cherskiy
# Processing Record 8 of Set 2 | new glasgow
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | qandala
# Processing Record 12 of Set 2 | sur
# Processing Record 13 of Set 2 | kantunilkin
# Processing Record 14 of Set 2 | jamestown
# Processing Record 15 of Set 2 | maniitsoq
# Processing Record 16 of Set 2 | skoghall
# Processing Record 17 of Set 2 | olafsvik
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | pangnirtung
# Processing Record 20 of Set 2 | bubaque
# Processing Record 21 of Set 2 | keokuk
# Processing Record 22 of Set 2 | mount isa
# Processing Record 23 of Set 2 | maldonado
# Processing Record 24 of Set 2 | nenagh
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | barra do corda
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | solano
# Processing Record 30 of Set 2 | hvammstangi
# City not found. Skipping...
# Processing Record 31 of Set 2 | magadi
# Processing Record 32 of Set 2 | barrow
# Processing Record 33 of Set 2 | matara
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | fereydun kenar
# Processing Record 37 of Set 2 | clyde river
# Processing Record 38 of Set 2 | yuzhou
# Processing Record 39 of Set 2 | codrington
# Processing Record 40 of Set 2 | coihaique
# Processing Record 41 of Set 2 | salalah
# Processing Record 42 of Set 2 | san francisco del mar
# Processing Record 43 of Set 2 | bilsanda
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | fortuna
# Processing Record 46 of Set 2 | vao
# Processing Record 47 of Set 2 | aketi
# Processing Record 48 of Set 2 | porto novo
# Processing Record 49 of Set 2 | boyolangu
# Processing Record 50 of Set 2 | leningradskiy
# Processing Record 1 of Set 3 | namibe
# Processing Record 2 of Set 3 | tonekabon
# Processing Record 3 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 3 | luanda
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 7 of Set 3 | paciran
# Processing Record 8 of Set 3 | vila velha
# Processing Record 9 of Set 3 | quelimane
# Processing Record 10 of Set 3 | kondinskoye
# Processing Record 11 of Set 3 | cabo san lucas
# Processing Record 12 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 3 | chamba
# Processing Record 14 of Set 3 | vuktyl
# Processing Record 15 of Set 3 | palmer
# Processing Record 16 of Set 3 | vanavara
# Processing Record 17 of Set 3 | luau
# Processing Record 18 of Set 3 | gudivada
# Processing Record 19 of Set 3 | tiarei
# Processing Record 20 of Set 3 | bayir
# Processing Record 21 of Set 3 | enshi
# Processing Record 22 of Set 3 | baykit
# Processing Record 23 of Set 3 | paarl
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | tilichiki
# Processing Record 26 of Set 3 | toowoomba
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 28 of Set 3 | hasaki
# Processing Record 29 of Set 3 | oksfjord
# Processing Record 30 of Set 3 | klaksvik
# Processing Record 31 of Set 3 | norman wells
# Processing Record 32 of Set 3 | chokurdakh
# Processing Record 33 of Set 3 | yellowknife
# Processing Record 34 of Set 3 | lagunillas
# Processing Record 35 of Set 3 | sishui
# Processing Record 36 of Set 3 | hualmay
# Processing Record 37 of Set 3 | geraldton
# Processing Record 38 of Set 3 | fortuna foothills
# Processing Record 39 of Set 3 | sept-iles
# Processing Record 40 of Set 3 | timra
# Processing Record 41 of Set 3 | bilibino
# Processing Record 42 of Set 3 | santa isabel do rio negro
# Processing Record 43 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 44 of Set 3 | los llanos de aridane
# Processing Record 45 of Set 3 | sakakah
# Processing Record 46 of Set 3 | samarai
# Processing Record 47 of Set 3 | nouadhibou
# Processing Record 48 of Set 3 | mount gambier
# Processing Record 49 of Set 3 | laguna
# Processing Record 50 of Set 3 | nome
# Processing Record 1 of Set 4 | broken hill
# Processing Record 2 of Set 4 | fort nelson
# Processing Record 3 of Set 4 | sompeta
# Processing Record 4 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 4 | kirovskiy
# Processing Record 6 of Set 4 | pyu
# Processing Record 7 of Set 4 | port elizabeth
# Processing Record 8 of Set 4 | barra do garcas
# Processing Record 9 of Set 4 | bluff
# Processing Record 10 of Set 4 | victor harbor
# Processing Record 11 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 4 | bonavista
# Processing Record 13 of Set 4 | guerrero negro
# Processing Record 14 of Set 4 | saiha
# Processing Record 15 of Set 4 | new norfolk
# Processing Record 16 of Set 4 | lerwick
# Processing Record 17 of Set 4 | gigmoto
# Processing Record 18 of Set 4 | oulainen
# Processing Record 19 of Set 4 | esperance
# Processing Record 20 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 4 | katangli
# Processing Record 22 of Set 4 | banda aceh
# Processing Record 23 of Set 4 | colwyn bay
# Processing Record 24 of Set 4 | pinheiro machado
# Processing Record 25 of Set 4 | hamilton
# Processing Record 26 of Set 4 | liyang
# Processing Record 27 of Set 4 | port alfred
# Processing Record 28 of Set 4 | xinqing
# Processing Record 29 of Set 4 | tigil
# Processing Record 30 of Set 4 | saint george
# Processing Record 31 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 4 | kampot
# Processing Record 33 of Set 4 | sao joao da barra
# Processing Record 34 of Set 4 | bengkulu
# Processing Record 35 of Set 4 | kavieng
# Processing Record 36 of Set 4 | praia
# Processing Record 37 of Set 4 | chiapilla
# Processing Record 38 of Set 4 | lebu
# Processing Record 39 of Set 4 | east london
# Processing Record 40 of Set 4 | pangai
# Processing Record 41 of Set 4 | antofagasta
# Processing Record 42 of Set 4 | saint-augustin
# Processing Record 43 of Set 4 | chala
# Processing Record 44 of Set 4 | dikson
# Processing Record 45 of Set 4 | rio grande
# Processing Record 46 of Set 4 | buin
# Processing Record 47 of Set 4 | constitucion
# Processing Record 48 of Set 4 | puerto carreno
# Processing Record 49 of Set 4 | hokitika
# Processing Record 50 of Set 4 | lamu
# Processing Record 1 of Set 5 | cabedelo
# Processing Record 2 of Set 5 | chabahar
# Processing Record 3 of Set 5 | simbahan
# Processing Record 4 of Set 5 | komsomolskiy
# Processing Record 5 of Set 5 | khandbari
# Processing Record 6 of Set 5 | port hedland
# Processing Record 7 of Set 5 | tarabuco
# Processing Record 8 of Set 5 | tomatlan
# Processing Record 9 of Set 5 | varel
# Processing Record 10 of Set 5 | rapid valley
# Processing Record 11 of Set 5 | henties bay
# Processing Record 12 of Set 5 | ostrovnoy
# Processing Record 13 of Set 5 | lasa
# Processing Record 14 of Set 5 | pundri
# Processing Record 15 of Set 5 | alofi
# Processing Record 16 of Set 5 | podgornoye
# Processing Record 17 of Set 5 | qaanaaq
# Processing Record 18 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 5 | akim swedru
# Processing Record 20 of Set 5 | little current
# Processing Record 21 of Set 5 | waingapu
# Processing Record 22 of Set 5 | nyurba
# Processing Record 23 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 5 | northam
# Processing Record 25 of Set 5 | hay river
# Processing Record 26 of Set 5 | teacapan
# Processing Record 27 of Set 5 | maicao
# Processing Record 28 of Set 5 | solnechnyy
# Processing Record 29 of Set 5 | carbonia
# Processing Record 30 of Set 5 | gohpur
# Processing Record 31 of Set 5 | rantepao
# Processing Record 32 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 5 | alushta
# Processing Record 34 of Set 5 | foshan
# Processing Record 35 of Set 5 | caravelas
# Processing Record 36 of Set 5 | kamenka
# Processing Record 37 of Set 5 | boddam
# Processing Record 38 of Set 5 | panormos
# Processing Record 39 of Set 5 | ilulissat
# Processing Record 40 of Set 5 | harper
# Processing Record 41 of Set 5 | richards bay
# Processing Record 42 of Set 5 | katerero
# Processing Record 43 of Set 5 | portel
# Processing Record 44 of Set 5 | mahajanga
# Processing Record 45 of Set 5 | hauterive
# Processing Record 46 of Set 5 | falmouth
# Processing Record 47 of Set 5 | perama
# Processing Record 48 of Set 5 | shimoda
# Processing Record 49 of Set 5 | portland
# Processing Record 50 of Set 5 | necochea
# Processing Record 1 of Set 6 | montepuez
# Processing Record 2 of Set 6 | pemberton
# Processing Record 3 of Set 6 | sawtell
# Processing Record 4 of Set 6 | alta
# Processing Record 5 of Set 6 | prince rupert
# Processing Record 6 of Set 6 | muncar
# Processing Record 7 of Set 6 | adeje
# Processing Record 8 of Set 6 | kingston
# Processing Record 9 of Set 6 | manzhouli
# Processing Record 10 of Set 6 | khromtau
# Processing Record 11 of Set 6 | tongliao
# Processing Record 12 of Set 6 | sitka
# Processing Record 13 of Set 6 | talnakh
# Processing Record 14 of Set 6 | georgetown
# Processing Record 15 of Set 6 | bethel
# Processing Record 16 of Set 6 | jardim
# Processing Record 17 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 6 | caxias
# Processing Record 19 of Set 6 | lewistown
# Processing Record 20 of Set 6 | teya
# Processing Record 21 of Set 6 | muroto
# Processing Record 22 of Set 6 | byron bay
# Processing Record 23 of Set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 24 of Set 6 | ndele
# Processing Record 25 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 6 | olden
# Processing Record 27 of Set 6 | kalmunai
# Processing Record 28 of Set 6 | cockburn town
# Processing Record 29 of Set 6 | carutapera
# Processing Record 30 of Set 6 | alta floresta
# Processing Record 31 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 6 | opuwo
# Processing Record 33 of Set 6 | denpasar
# Processing Record 34 of Set 6 | quthing
# Processing Record 35 of Set 6 | hatsukaichi
# Processing Record 36 of Set 6 | pljevlja
# Processing Record 37 of Set 6 | kahului
# Processing Record 38 of Set 6 | bathsheba
# Processing Record 39 of Set 6 | bud
# Processing Record 40 of Set 6 | masindi
# Processing Record 41 of Set 6 | qaqortoq
# Processing Record 42 of Set 6 | faya
# Processing Record 43 of Set 6 | krasnoselkup
# Processing Record 44 of Set 6 | oregon
# Processing Record 45 of Set 6 | mulheim-karlich
# Processing Record 46 of Set 6 | upernavik
# Processing Record 47 of Set 6 | saint-pierre
# Processing Record 48 of Set 6 | mar del plata
# Processing Record 49 of Set 6 | pisco
# Processing Record 50 of Set 6 | haines junction
# Processing Record 1 of Set 7 | southbridge
# Processing Record 2 of Set 7 | san rafael
# Processing Record 3 of Set 7 | mirzapur
# Processing Record 4 of Set 7 | kirksville
# Processing Record 5 of Set 7 | longyearbyen
# Processing Record 6 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 7 of Set 7 | sawakin
# Processing Record 8 of Set 7 | vostok
# Processing Record 9 of Set 7 | shimoni
# Processing Record 10 of Set 7 | narsaq
# Processing Record 11 of Set 7 | chapais
# Processing Record 12 of Set 7 | asekeyevo
# Processing Record 13 of Set 7 | burica
# City not found. Skipping...
# Processing Record 14 of Set 7 | cayenne
# Processing Record 15 of Set 7 | abalak
# Processing Record 16 of Set 7 | sorland
# Processing Record 17 of Set 7 | san patricio
# Processing Record 18 of Set 7 | haicheng
# Processing Record 19 of Set 7 | rawson
# Processing Record 20 of Set 7 | pevek
# Processing Record 21 of Set 7 | ponta delgada
# Processing Record 22 of Set 7 | piskivka
# Processing Record 23 of Set 7 | santa maria
# Processing Record 24 of Set 7 | kangaatsiaq
# Processing Record 25 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 26 of Set 7 | ostersund
# Processing Record 27 of Set 7 | roald
# Processing Record 28 of Set 7 | merauke
# Processing Record 29 of Set 7 | arandis
# Processing Record 30 of Set 7 | novobiryusinskiy
# Processing Record 31 of Set 7 | linchuan
# City not found. Skipping...
# Processing Record 32 of Set 7 | kargil
# Processing Record 33 of Set 7 | nkowakowa
# Processing Record 34 of Set 7 | kokkola
# Processing Record 35 of Set 7 | kyra
# Processing Record 36 of Set 7 | korla
# Processing Record 37 of Set 7 | tessalit
# Processing Record 38 of Set 7 | orlik
# Processing Record 39 of Set 7 | laje
# Processing Record 40 of Set 7 | broome
# Processing Record 41 of Set 7 | beloha
# Processing Record 42 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 7 | ancud
# Processing Record 44 of Set 7 | boende
# Processing Record 45 of Set 7 | isangel
# Processing Record 46 of Set 7 | nyrob
# Processing Record 47 of Set 7 | springbok
# Processing Record 48 of Set 7 | corner brook
# Processing Record 49 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 7 | mmabatho
# Processing Record 1 of Set 8 | erdenet
# Processing Record 2 of Set 8 | porto belo
# Processing Record 3 of Set 8 | nizhnyaya tavda
# Processing Record 4 of Set 8 | maneromango
# Processing Record 5 of Set 8 | grindavik
# Processing Record 6 of Set 8 | grand gaube
# Processing Record 7 of Set 8 | kawalu
# Processing Record 8 of Set 8 | yeppoon
# Processing Record 9 of Set 8 | ribnitz-damgarten
# Processing Record 10 of Set 8 | severnyy
# Processing Record 11 of Set 8 | nikel
# Processing Record 12 of Set 8 | severo-kurilsk
# Processing Record 13 of Set 8 | alexandria
# Processing Record 14 of Set 8 | morehead
# Processing Record 15 of Set 8 | quatre cocos
# Processing Record 16 of Set 8 | qianan
# Processing Record 17 of Set 8 | lavrentiya
# Processing Record 18 of Set 8 | galle
# Processing Record 19 of Set 8 | novodugino
# Processing Record 20 of Set 8 | altamira
# Processing Record 21 of Set 8 | ketchikan
# Processing Record 22 of Set 8 | meulaboh
# Processing Record 23 of Set 8 | yar-sale
# Processing Record 24 of Set 8 | castro
# Processing Record 25 of Set 8 | pangoa
# Processing Record 26 of Set 8 | lompoc
# Processing Record 27 of Set 8 | moron
# Processing Record 28 of Set 8 | kawai
# Processing Record 29 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 8 | pavlikeni
# Processing Record 31 of Set 8 | rafraf
# Processing Record 32 of Set 8 | hami
# Processing Record 33 of Set 8 | zyryanka
# Processing Record 34 of Set 8 | imbituba
# Processing Record 35 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 36 of Set 8 | hambantota
# Processing Record 37 of Set 8 | molteno
# Processing Record 38 of Set 8 | gamba
# Processing Record 39 of Set 8 | nuuk
# Processing Record 40 of Set 8 | puerto princesa
# Processing Record 41 of Set 8 | katherine
# Processing Record 42 of Set 8 | san cristobal
# Processing Record 43 of Set 8 | la paz
# Processing Record 44 of Set 8 | auch
# Processing Record 45 of Set 8 | beian
# Processing Record 46 of Set 8 | peterhead
# Processing Record 47 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 8 | roma
# Processing Record 49 of Set 8 | tolbazy
# Processing Record 50 of Set 8 | kruisfontein
# Processing Record 1 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 9 | menongue
# Processing Record 3 of Set 9 | chern
# Processing Record 4 of Set 9 | speightstown
# Processing Record 5 of Set 9 | kushima
# Processing Record 6 of Set 9 | luderitz
# Processing Record 7 of Set 9 | susanville
# Processing Record 8 of Set 9 | saskylakh
# Processing Record 9 of Set 9 | tandil
# Processing Record 10 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 9 | port macquarie
# Processing Record 12 of Set 9 | tautira
# Processing Record 13 of Set 9 | nelson bay
# Processing Record 14 of Set 9 | san jose
# Processing Record 15 of Set 9 | qasigiannguit
# Processing Record 16 of Set 9 | moose factory
# Processing Record 17 of Set 9 | ambilobe
# Processing Record 18 of Set 9 | pedasi
# Processing Record 19 of Set 9 | bonthe
# Processing Record 20 of Set 9 | grand-bourg
# Processing Record 21 of Set 9 | cairns
# Processing Record 22 of Set 9 | fort dodge
# Processing Record 23 of Set 9 | trat
# Processing Record 24 of Set 9 | kitimat
# Processing Record 25 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 27 of Set 9 | raudeberg
# Processing Record 28 of Set 9 | bure
# Processing Record 29 of Set 9 | denia
# Processing Record 30 of Set 9 | flin flon
# Processing Record 31 of Set 9 | doha
# Processing Record 32 of Set 9 | ayna
# Processing Record 33 of Set 9 | acari
# Processing Record 34 of Set 9 | faanui
# Processing Record 35 of Set 9 | mayumba
# Processing Record 36 of Set 9 | nizwa
# Processing Record 37 of Set 9 | russell
# Processing Record 38 of Set 9 | inhambane
# Processing Record 39 of Set 9 | iskateley
# Processing Record 40 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 9 | goma
# Processing Record 42 of Set 9 | saint-georges
# Processing Record 43 of Set 9 | pochutla
# Processing Record 44 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 9 | riyadh
# Processing Record 46 of Set 9 | cape canaveral
# Processing Record 47 of Set 9 | san andres
# Processing Record 48 of Set 9 | deori khas
# Processing Record 49 of Set 9 | fulacunda
# City not found. Skipping...
# Processing Record 50 of Set 9 | la ronge
# Processing Record 1 of Set 10 | glenwood springs
# Processing Record 2 of Set 10 | vylkove
# Processing Record 3 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 4 of Set 10 | mujiayingzi
# Processing Record 5 of Set 10 | urusha
# Processing Record 6 of Set 10 | kalaleh
# Processing Record 7 of Set 10 | alenquer
# Processing Record 8 of Set 10 | baiao
# Processing Record 9 of Set 10 | wajima
# Processing Record 10 of Set 10 | torbay
# Processing Record 11 of Set 10 | touros
# Processing Record 12 of Set 10 | mangan
# Processing Record 13 of Set 10 | tukrah
# Processing Record 14 of Set 10 | san quintin
# Processing Record 15 of Set 10 | huarmey
# Processing Record 16 of Set 10 | talaya
# Processing Record 17 of Set 10 | nhulunbuy
# Processing Record 18 of Set 10 | sao filipe
# Processing Record 19 of Set 10 | kaeo
# Processing Record 20 of Set 10 | el porvenir
# Processing Record 21 of Set 10 | chulym
# Processing Record 22 of Set 10 | kinanah
# City not found. Skipping...
# Processing Record 23 of Set 10 | christchurch
# Processing Record 24 of Set 10 | sioux lookout
# Processing Record 25 of Set 10 | ghanzi
# Processing Record 26 of Set 10 | galveston
# Processing Record 27 of Set 10 | mackay
# Processing Record 28 of Set 10 | belmonte
# Processing Record 29 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 31 of Set 10 | edd
# Processing Record 32 of Set 10 | lagoa
# Processing Record 33 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 34 of Set 10 | katsuura
# Processing Record 35 of Set 10 | marau
# Processing Record 36 of Set 10 | bar harbor
# Processing Record 37 of Set 10 | oum hadjer
# Processing Record 38 of Set 10 | malakal
# Processing Record 39 of Set 10 | dehui
# Processing Record 40 of Set 10 | barcelona
# Processing Record 41 of Set 10 | beringovskiy
# Processing Record 42 of Set 10 | ilhabela
# Processing Record 43 of Set 10 | ulaangom
# Processing Record 44 of Set 10 | rudnichnyy
# Processing Record 45 of Set 10 | shangrao
# Processing Record 46 of Set 10 | cam pha
# City not found. Skipping...
# Processing Record 47 of Set 10 | tineo
# Processing Record 48 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 49 of Set 10 | eirunepe
# Processing Record 50 of Set 10 | udachnyy
# Processing Record 1 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 2 of Set 11 | kununurra
# Processing Record 3 of Set 11 | port keats
# Processing Record 4 of Set 11 | hofn
# Processing Record 5 of Set 11 | simao
# Processing Record 6 of Set 11 | deputatskiy
# Processing Record 7 of Set 11 | dudinka
# Processing Record 8 of Set 11 | zatoka
# Processing Record 9 of Set 11 | spearfish
# Processing Record 10 of Set 11 | payson
# Processing Record 11 of Set 11 | liku
# Processing Record 12 of Set 11 | ciudad bolivar
# Processing Record 13 of Set 11 | manzanillo
# Processing Record 14 of Set 11 | swellendam
# Processing Record 15 of Set 11 | binga
# Processing Record 16 of Set 11 | arkhara
# Processing Record 17 of Set 11 | jomalig
# City not found. Skipping...
# Processing Record 18 of Set 11 | marienburg
# Processing Record 19 of Set 11 | potiskum
# Processing Record 20 of Set 11 | takaka
# Processing Record 21 of Set 11 | wattegama
# Processing Record 22 of Set 11 | veraval
# Processing Record 23 of Set 11 | hukuntsi
# Processing Record 24 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 11 | ginir
# Processing Record 26 of Set 11 | port augusta
# Processing Record 27 of Set 11 | chepareria
# Processing Record 28 of Set 11 | upington
# Processing Record 29 of Set 11 | novovorontsovka
# Processing Record 30 of Set 11 | calama
# Processing Record 31 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 11 | paita
# Processing Record 33 of Set 11 | pitimbu
# Processing Record 34 of Set 11 | matsanga
# City not found. Skipping...
# Processing Record 35 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 36 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 11 | sao borja
# Processing Record 38 of Set 11 | porkhov
# Processing Record 39 of Set 11 | umm lajj
# Processing Record 40 of Set 11 | ushtobe
# Processing Record 41 of Set 11 | nanortalik
# Processing Record 42 of Set 11 | bilma
# Processing Record 43 of Set 11 | high level
# Processing Record 44 of Set 11 | fukue
# Processing Record 45 of Set 11 | uyuni
# Processing Record 46 of Set 11 | dayong
# Processing Record 47 of Set 11 | grafenhainichen
# Processing Record 48 of Set 11 | kalangala
# Processing Record 49 of Set 11 | hobyo
# Processing Record 50 of Set 11 | clarence town
# Processing Record 1 of Set 12 | sovetskiy
# Processing Record 2 of Set 12 | el bordo
# Processing Record 3 of Set 12 | xingtai
# Processing Record 4 of Set 12 | muisne
# Processing Record 5 of Set 12 | dunedin
# Processing Record 6 of Set 12 | sambava
# Processing Record 7 of Set 12 | borogontsy
# Processing Record 8 of Set 12 | alice springs
# Processing Record 9 of Set 12 | bulawayo
# Processing Record 10 of Set 12 | sola
# Processing Record 11 of Set 12 | goderich
# Processing Record 12 of Set 12 | ngaoundere
# Processing Record 13 of Set 12 | tatawin
# Processing Record 14 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 16 of Set 12 | viedma
# Processing Record 17 of Set 12 | bereda
# Processing Record 18 of Set 12 | sombrio
# Processing Record 19 of Set 12 | camacha
# Processing Record 20 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 12 | kavaratti
# Processing Record 22 of Set 12 | itarema
# Processing Record 23 of Set 12 | tura
# Processing Record 24 of Set 12 | mareeba
# Processing Record 25 of Set 12 | milkovo
# Processing Record 26 of Set 12 | wodonga
# Processing Record 27 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 28 of Set 12 | turayf
# Processing Record 29 of Set 12 | elwood
# Processing Record 30 of Set 12 | saint-louis
# Processing Record 31 of Set 12 | vila franca do campo
# Processing Record 32 of Set 12 | bryan
# Processing Record 33 of Set 12 | mundwa
# Processing Record 34 of Set 12 | orbe
# Processing Record 35 of Set 12 | bukit bakri
# City not found. Skipping...
# Processing Record 36 of Set 12 | kilindoni
# Processing Record 37 of Set 12 | greystones
# Processing Record 38 of Set 12 | lazaro cardenas
# Processing Record 39 of Set 12 | kijang
# Processing Record 40 of Set 12 | sumkino
# Processing Record 41 of Set 12 | cururupu
# Processing Record 42 of Set 12 | doctor arroyo
# Processing Record 43 of Set 12 | port blair
# Processing Record 44 of Set 12 | chhatak
# Processing Record 45 of Set 12 | berlevag
# Processing Record 46 of Set 12 | lubyany
# Processing Record 47 of Set 12 | manta
# Processing Record 48 of Set 12 | san joaquin
# Processing Record 49 of Set 12 | waris aliganj
# Processing Record 50 of Set 12 | oriximina
# Processing Record 1 of Set 13 | sembabule
# Processing Record 2 of Set 13 | tuatapere
# Processing Record 3 of Set 13 | dauriya
# Processing Record 4 of Set 13 | santa cruz
# Processing Record 5 of Set 13 | shetpe
# Processing Record 6 of Set 13 | hashtrud
# Processing Record 7 of Set 13 | chachapoyas
# Processing Record 8 of Set 13 | dzaoudzi
# Processing Record 9 of Set 13 | port hardy
# Processing Record 10 of Set 13 | stawell
# Processing Record 11 of Set 13 | abha
# Processing Record 12 of Set 13 | ust-kuyga
# Processing Record 13 of Set 13 | kurilsk
# Processing Record 14 of Set 13 | kota kinabalu
# Processing Record 15 of Set 13 | dakar
# Processing Record 16 of Set 13 | lata
# Processing Record 17 of Set 13 | ballina
# Processing Record 18 of Set 13 | tecoanapa
# Processing Record 19 of Set 13 | anadyr
# Processing Record 20 of Set 13 | willmar
# Processing Record 21 of Set 13 | avera
# Processing Record 22 of Set 13 | neuquen
# Processing Record 23 of Set 13 | bequimao
# Processing Record 24 of Set 13 | almaznyy
# Processing Record 25 of Set 13 | texarkana
# Processing Record 26 of Set 13 | baraboo
# Processing Record 27 of Set 13 | linxia
# Processing Record 28 of Set 13 | gumushane
# City not found. Skipping...
# Processing Record 29 of Set 13 | sparta
# Processing Record 30 of Set 13 | saldanha
# Processing Record 31 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 32 of Set 13 | mitsamiouli
# Processing Record 33 of Set 13 | baghdad
# Processing Record 34 of Set 13 | paamiut
# Processing Record 35 of Set 13 | nalut
# Processing Record 36 of Set 13 | xingyi
# Processing Record 37 of Set 13 | mogok
# Processing Record 38 of Set 13 | emmett
# Processing Record 39 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 13 | xai-xai
# Processing Record 41 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 13 | beyneu
# Processing Record 43 of Set 13 | braganca
# Processing Record 44 of Set 13 | valley city
# Processing Record 45 of Set 13 | levelland
# Processing Record 46 of Set 13 | viesca
# Processing Record 47 of Set 13 | college
# Processing Record 48 of Set 13 | sarangani
# Processing Record 49 of Set 13 | sokolskoye
# Processing Record 50 of Set 13 | tooele
# Processing Record 1 of Set 14 | dubbo
# Processing Record 2 of Set 14 | aklavik
# Processing Record 3 of Set 14 | olinda
# Processing Record 4 of Set 14 | fare
# Processing Record 5 of Set 14 | zhanakorgan
# Processing Record 6 of Set 14 | disna
# Processing Record 7 of Set 14 | nioaque
# Processing Record 8 of Set 14 | bedele
# Processing Record 9 of Set 14 | auki
# Processing Record 10 of Set 14 | mayor pablo lagerenza
# Processing Record 11 of Set 14 | redmond
# Processing Record 12 of Set 14 | fulitun
# City not found. Skipping...
# Processing Record 13 of Set 14 | graaff-reinet
# Processing Record 14 of Set 14 | falam
# Processing Record 15 of Set 14 | sandpoint
# Processing Record 16 of Set 14 | lakes entrance
# Processing Record 17 of Set 14 | san juan
# Processing Record 18 of Set 14 | chihuahua
# Processing Record 19 of Set 14 | westport
# Processing Record 20 of Set 14 | corsicana
# Processing Record 21 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 14 | salinas
# Processing Record 23 of Set 14 | cocachacra
# Processing Record 24 of Set 14 | puerto escondido
# Processing Record 25 of Set 14 | kungurtug
# Processing Record 26 of Set 14 | yashkul
# Processing Record 27 of Set 14 | kahama
# Processing Record 28 of Set 14 | bara
# Processing Record 29 of Set 14 | kamloops
# Processing Record 30 of Set 14 | ambulu
# Processing Record 31 of Set 14 | flinders
# Processing Record 32 of Set 14 | assare
# Processing Record 33 of Set 14 | donauworth
# Processing Record 34 of Set 14 | sanvordem
# Processing Record 35 of Set 14 | sijunjung
# Processing Record 36 of Set 14 | lakatoro
# Processing Record 37 of Set 14 | baherden
# Processing Record 38 of Set 14 | onega
# Processing Record 39 of Set 14 | kaiyuan
# Processing Record 40 of Set 14 | namatanai
# Processing Record 41 of Set 14 | port lincoln
# Processing Record 42 of Set 14 | mariinsk
# Processing Record 43 of Set 14 | along
# Processing Record 44 of Set 14 | puerto del rosario
# Processing Record 45 of Set 14 | irbil
# Processing Record 46 of Set 14 | muros
# Processing Record 47 of Set 14 | salekhard
# Processing Record 48 of Set 14 | champerico
# Processing Record 49 of Set 14 | kloulklubed
# Processing Record 50 of Set 14 | lokosovo
# Processing Record 1 of Set 15 | ylivieska
# Processing Record 2 of Set 15 | sibolga
# Processing Record 3 of Set 15 | poum
# Processing Record 4 of Set 15 | cam ranh
# Processing Record 5 of Set 15 | banjar
# Processing Record 6 of Set 15 | damascus
# Processing Record 7 of Set 15 | klyuchevskiy
# Processing Record 8 of Set 15 | shieli
# Processing Record 9 of Set 15 | mahanoro
# Processing Record 10 of Set 15 | tambura
# Processing Record 11 of Set 15 | tocopilla
# Processing Record 12 of Set 15 | barabai
# Processing Record 13 of Set 15 | gorom-gorom
# Processing Record 14 of Set 15 | bafra
# Processing Record 15 of Set 15 | inverness
# Processing Record 16 of Set 15 | masalli
# Processing Record 17 of Set 15 | vardo
# Processing Record 18 of Set 15 | mecca
# Processing Record 19 of Set 15 | pauini
# Processing Record 20 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 21 of Set 15 | kushiro
# Processing Record 22 of Set 15 | san fernando
# Processing Record 23 of Set 15 | acapulco
# Processing Record 24 of Set 15 | waimana
# Processing Record 25 of Set 15 | shakhrinau
# City not found. Skipping...
# Processing Record 26 of Set 15 | la palma
# Processing Record 27 of Set 15 | kanniyakumari
# Processing Record 28 of Set 15 | ewa beach
# Processing Record 29 of Set 15 | yaan
# Processing Record 30 of Set 15 | labytnangi
# Processing Record 31 of Set 15 | kenai
# Processing Record 32 of Set 15 | axim
# Processing Record 33 of Set 15 | bharatpur
# Processing Record 34 of Set 15 | jiaonan
# Processing Record 35 of Set 15 | camopi
# Processing Record 36 of Set 15 | saint-joseph
# Processing Record 37 of Set 15 | mirpur bathoro
# City not found. Skipping...
# Processing Record 38 of Set 15 | sendhwa
# Processing Record 39 of Set 15 | khani
# Processing Record 40 of Set 15 | japura
# Processing Record 41 of Set 15 | zenzeli
# Processing Record 42 of Set 15 | isla vista
# Processing Record 43 of Set 15 | vargashi
# Processing Record 44 of Set 15 | camocim
# Processing Record 45 of Set 15 | kurumkan
# Processing Record 46 of Set 15 | hervey bay
# Processing Record 47 of Set 15 | warrington
# Processing Record 48 of Set 15 | jumla
# Processing Record 49 of Set 15 | segezha
# Processing Record 50 of Set 15 | amapa
# Processing Record 1 of Set 16 | halifax
# Processing Record 2 of Set 16 | ahipara
# Processing Record 3 of Set 16 | dwarka
# Processing Record 4 of Set 16 | bundaberg
# Processing Record 5 of Set 16 | half moon bay
# Processing Record 6 of Set 16 | mandan
# Processing Record 7 of Set 16 | saint-francois
# Processing Record 8 of Set 16 | micheweni
# Processing Record 9 of Set 16 | naze
# Processing Record 10 of Set 16 | srivardhan
# Processing Record 11 of Set 16 | jasdan
# Processing Record 12 of Set 16 | sofiysk
# City not found. Skipping...
# Processing Record 13 of Set 16 | aquin
# Processing Record 14 of Set 16 | lingao
# Processing Record 15 of Set 16 | praia da vitoria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 699

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Thompson  55.7435  -97.8558     33.80        93          90
# 1        Dolores -36.3132  -57.6792     66.67        88          36
# 2         Albany  42.6001  -73.9662     59.00        22          20
# 3     Kaitangata -46.2817  169.8464     64.00        45          16
# 4         Camiri -20.0500  -63.5167     80.60        69          90
# 5       Cidreira -30.1811  -50.2056     73.44        78          82
# 6  Saint Anthony  45.0205  -93.2180     84.20        28          20
# 7        Margate  51.3813    1.3862     39.99        42           6
# 8       Tasiilaq  65.6145  -37.6368     15.80        86          75
# 9   Puerto Ayora  -0.7393  -90.3518     86.00        66          20
#
#    Wind Speed Country Current Description
# 0       14.97      CA          light snow
# 1        7.94      AR    scattered clouds
# 2       14.97      US          few clouds
# 3       15.01      NZ          few clouds
# 4        4.09      BO     overcast clouds
# 5       16.37      BR       broken clouds
# 6       11.50      US          few clouds
# 7        8.01      GB           clear sky
# 8       21.85      GL          light rain
# 9       17.27      EC          few clouds

# %%
# Reorder Columns 
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Thompson      CA  55.7435  -97.8558     33.80        93          90
# 1        Dolores      AR -36.3132  -57.6792     66.67        88          36
# 2         Albany      US  42.6001  -73.9662     59.00        22          20
# 3     Kaitangata      NZ -46.2817  169.8464     64.00        45          16
# 4         Camiri      BO -20.0500  -63.5167     80.60        69          90
# 5       Cidreira      BR -30.1811  -50.2056     73.44        78          82
# 6  Saint Anthony      US  45.0205  -93.2180     84.20        28          20
# 7        Margate      GB  51.3813    1.3862     39.99        42           6
# 8       Tasiilaq      GL  65.6145  -37.6368     15.80        86          75
# 9   Puerto Ayora      EC  -0.7393  -90.3518     86.00        66          20
#
#    Wind Speed Current Description
# 0       14.97          light snow
# 1        7.94    scattered clouds
# 2       14.97          few clouds
# 3       15.01          few clouds
# 4        4.09     overcast clouds
# 5       16.37       broken clouds
# 6       11.50          few clouds
# 7        8.01           clear sky
# 8       21.85          light rain
# 9       17.27          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
